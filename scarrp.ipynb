# %%
## all imports
from IPython.display import HTML
import numpy as np
import urllib3 
import bs4 #this is beautiful soup
import time
import operator
import socket
import pickle
import re # regular expressions


from pandas import Series
import pandas as pd
from pandas import DataFrame

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set_context("talk")
sns.set_style("white")

from secrets import *

# %%
import requests

# %%
from bs4 import BeautifulSoup
urllib3.disable_warnings()

url = "https://www.goodreads.com/choiceawards/best-fiction-books-2017"

http=urllib3.PoolManager()
respond=http.request("Get",url)
soup = BeautifulSoup(respond.data,"lxml")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="desktop ">
#  <head>
#   <title>
#    Best Fiction 2017 — Goodreads Choice Awards
#   </title>
#   <script type="text/javascript">
#    if (window.Mobvious === undefined) {
#           window.Mobvious = {};
#         }
#         window.Mobvious.device_type = 'desktop';
#   </script>
#   <script src="https://s.gr-assets.com/assets/webfontloader-f2373eb97b67c818c1db5c9392e387af.js">
#   </script>
#   <script>
#    //<![CDATA[
#
#   WebFont.load({
#     classes: false,
#     custom: {
#       families: ["Lato:n4,n7,i4", "Merriweather:n4,n7,i4"],
#       urls: ["https://s.gr-assets.com/assets/gr/fonts-e256f84093cc13b27f5b82343398031a.css"]
#     }
#   });
#
# //]]>
#   </script>
#   <link href="https://s.gr-assets.com/assets/goodreads-bf240c2889a893d3bc5cd774a525814d.css" media="all" rel="stylesheet"/>
#   <!--[if lte IE 9]>
# <link rel="stylesheet" media="all" href="https://s.gr-assets.com/assets/goodreads_split2-8d8f5f37a21c582d17614442bacf19a6.css" />
# ...

# %%
soup.find_all("img")
# Out:
# [<img alt="2017 Goodreads Choice Awards" height="" id="choiceLogo" src="https://s.gr-assets.com/assets/award/2017/choice-logo-large-f58652574937de729c5678752332c840.png" title="2017 Goodreads Choice Awards" width=""/>,
#  <img alt="F29" src="https://s.gr-assets.com/assets/facebook/f29-fb02e22e90b143c997e641e721ec9d24.png"/>,
#  <img alt="Twitter 18x18" src="https://s.gr-assets.com/assets/icons/twitter-18x18-366efce03683da7dbcba7878e04010ef.png"/>,
#  <img alt="Little Fires Everywhere by Celeste Ng" src="https://images.gr-assets.com/books/1522684533l/34273236.jpg" title="Little Fires Everywhere by Celeste Ng"/>,
#  <img alt="saving…" class="progressIndicator" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif"/>,
#  <img alt="saving…" class="progressIndicator" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif"/>,
# ...

# %%
mydivs = soup.findAll("div", {"class": "stylelistrow"})

# %%
mydiv=soup.find_all("div",{"class":"inlineblock pollAnswer resultShown"})

# %%
link_list = [l.get('href') for l in soup.findAll("div",{"class":"inlineblock pollAnswer resultShown"})]
link_list
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
# You tell Python that you want to use a library with the import statement.
import requests

# %%
op=requests.get("https://en.wikipedia.org/wiki/Harvard_University")

# %%
op
# Out:
# <Response [200]>

# %% [markdown]
# sice we knoe ''_str()_'' amd "_repr_" are inbuilt funtion of an object so can be used to overrite the what they print in print function and now in this request object has by default the request code 200 means succesful??
# also we can use dir to find all the attributes and the functons t keep thing in mind

# %%
dir(op)
# Out:
# ['__attrs__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_content',
#  '_content_consumed',
#  '_next',
#  'apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'next',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url']

# %%
import json

# %%
dir(json)
# Out:
# ['JSONDecodeError',
#  'JSONDecoder',
#  'JSONEncoder',
#  '__all__',
#  '__author__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_default_decoder',
#  '_default_encoder',
#  'codecs',
#  'decoder',
#  'detect_encoding',
#  'dump',
#  'dumps',
#  'encoder',
#  'load',
#  'loads',
#  'scanner']

# %%
from bs4 import BeautifulSoup

# %%
page=op.text
soup=BeautifulSoup(page,"html.parser")

# %%
type(page),type(op)
# Out:
# (str, requests.models.Response)

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Harvard University - Wikipedia</title>
# <script>document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );</script>
# ...

# %%
lis=soup.find_all("link")

# %%
lis
# Out:
# [<link href="/w/load.php?debug=false&amp;lang=en&amp;modules=ext.cite.styles%7Cext.math.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.tablesorter.styles%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.page.gallery.styles%7Cmediawiki.skinning.interface%7Cskins.vector.styles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector" rel="stylesheet"/>,
#  <link href="/w/load.php?debug=false&amp;lang=en&amp;modules=ext.gadget.charinsert-styles&amp;only=styles&amp;skin=vector" rel="stylesheet"/>,
#  <link href="/w/load.php?debug=false&amp;lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector" rel="stylesheet"/>,
#  <link href="android-app://org.wikipedia/http/en.m.wikipedia.org/wiki/Harvard_University" rel="alternate"/>,
#  <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>,
#  <link href="/static/favicon/wikipedia.ico" rel="shortcut icon"/>,
# ...

# %%
soup.find_all("table")
# Out:
# [<table class="infobox vcard" style="width:22em">
#  <caption class="fn org">Harvard University</caption>
#  <tr>
#  <td colspan="2" style="text-align:center"><a class="image" href="/wiki/File:Harvard_shield_wreath.svg"><img alt="Harvard shield wreath.svg" data-file-height="243" data-file-width="250" height="175" src="//upload.wikimedia.org/wikipedia/en/thumb/2/29/Harvard_shield_wreath.svg/180px-Harvard_shield_wreath.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/2/29/Harvard_shield_wreath.svg/270px-Harvard_shield_wreath.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/2/29/Harvard_shield_wreath.svg/360px-Harvard_shield_wreath.svg.png 2x" width="180"/></a>
#  <div><a href="/wiki/Heraldry_of_Harvard_University#Harvard_University_coat_of_arms" title="Heraldry of Harvard University">Coat of arms</a></div>
#  </td>
#  </tr>
#  <tr>
# ...

# %%
listy=[]
for t in soup.find_all("table"):
    if t.get("class"):
        listy.append(t["class"])
        
listy
# Out:
# [['infobox', 'vcard'],
#  ['toccolours'],
#  ['plainlinks', 'metadata', 'ambox', 'mbox-small-left', 'ambox-content'],
#  ['multicol'],
#  ['infobox'],
#  ['wikitable', 'sortable', 'collapsible', 'collapsed'],
#  ['wikitable', 'sortable', 'collapsible', 'collapsed'],
#  ['wikitable'],
#  ['nowraplinks', 'collapsible', 'collapsed', 'navbox-inner'],
#  ['nowraplinks', 'navbox-subgroup'],
#  ['nowraplinks', 'navbox-subgroup'],
#  ['nowraplinks', 'collapsible', 'collapsed', 'navbox-inner'],
#  ['nowraplinks', 'collapsible', 'autocollapse', 'navbox-inner'],
#  ['nowraplinks', 'collapsible', 'autocollapse', 'navbox-inner'],
#  ['nowraplinks', 'collapsible', 'autocollapse', 'navbox-inner'],
#  ['nowraplinks', 'collapsible', 'autocollapse', 'navbox-inner'],
#  ['nowraplinks', 'collapsible', 'autocollapse', 'navbox-inner'],
#  ['nowraplinks', 'collapsible', 'autocollapse', 'navbox-inner'],
#  ['nowraplinks', 'collapsible', 'autocollapse', 'navbox-inner'],
# ...

# %%
soup.table["class"]
# Out:
# ['infobox', 'vcard']

# %%
table_html = str(soup.find("table", "wikitable"))# this thing is soup object find for table and

# %%
from IPython.core.display import HTML

HTML(table_html)
# Out:
# <table class="wikitable sortable collapsible collapsed" style="float:right">
# <tr>
# <th colspan="4" style="background-color:#A51C30;color:white;-moz-box-shadow: inset 2px 2px 0 #1E1E1E, inset -2px -2px 0 #1E1E1E; -webkit-box-shadow: inset 2px 2px 0 #1E1E1E, inset -2px -2px 0 #1E1E1E; box-shadow: inset 2px 2px 0 #1E1E1E, inset -2px -2px 0 #1E1E1E;">National Program Rankings<sup class="reference" id="cite_ref-USNWR_Grad_School_Rankings_130-0"><a href="#cite_note-USNWR_Grad_School_Rankings-130">[130]</a></sup></th>
# </tr>
# <tr>
# <th>Program</th>
# <th>Ranking</th>
# </tr>
# <tr>
# <td>Biological Sciences</td>
# <td>1</td>
# </tr>
# <tr>
# <td>Business</td>
# <td>1</td>
# </tr>
# <tr>
# <td>Chemistry</td>
# <td>4</td>
# </tr>
# <tr>
# <td>Clinical Psychology</td>
# <td>16</td>
# </tr>
# <tr>
# <td>Computer Science</td>
# <td>18</td>
# </tr>
# <tr>
# <td>Earth Sciences</td>
# <td>8</td>
# </tr>
# <tr>
# <td>Economics</td>
# <td>1</td>
# </tr>
# <tr>
# <td>Education</td>
# <td>1</td>
# ...

# %%
import requests

# %%
req_obj=requests.get("https://www.goodreads.com/list/show/1.Best_Books_Ever")

# %%
type(req_obj)
# Out:
# requests.models.Response

# %%
page=req_obj.text

# %%
page
# Out:
# '<!DOCTYPE html>\n<html class="desktop\n">\n\n\n<head>\n  <title>\nBest Books Ever (53177 books)\n</title>\n\n\n    <script type="text/javascript"> var ue_t0=window.ue_t0||+new Date();\n </script>\n  <script type="text/javascript">\n    (function(e){var c=e;var a=c.ue||{};a.main_scope="mainscopecsm";a.q=[];a.t0=c.ue_t0||+new Date();a.d=g;function g(h){return +new Date()-(h?0:a.t0)}function d(h){return function(){a.q.push({n:h,a:arguments,t:a.d()})}}function b(m,l,h,j,i){var k={m:m,f:l,l:h,c:""+j,err:i,fromOnError:1,args:arguments};c.ueLogError(k);return false}b.skipTrace=1;e.onerror=b;function f(){c.uex("ld")}if(e.addEventListener){e.addEventListener("load",f,false)}else{if(e.attachEvent){e.attachEvent("onload",f)}}a.tag=d("tag");a.log=d("log");a.reset=d("rst");c.ue_csm=c;c.ue=a;c.ueLogError=d("err");c.ues=d("ues");c.uet=d("uet");c.uex=d("uex");c.uet("ue")})(window);(function(e,d){var a=e.ue||{};function c(g){if(!g){return}var f=d.head||d.getElementsByTagName("head")[0]||d.documentEl
# ...

# %%
from bs4 import BeautifulSoup

# %%
soup=BeautifulSoup(page,"html.parser")

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html class="desktop ">
# <head>
# <title>
# Best Books Ever (53177 books)
# </title>
# <script type="text/javascript"> var ue_t0=window.ue_t0||+new Date();
#  </script>
# <script type="text/javascript">
# ...

# %%
s1=soup.find_all("span",itemprop="name")
#import pandas as pd

# %%
a=soup.find_all("span",class_="minirating")
for alp in a :
    print(alp.get_text())
# Out:
#  4.33 avg rating — 5,349,156 ratings
#  4.47 avg rating — 1,973,661 ratings
#  4.26 avg rating — 3,598,198 ratings
#  4.25 avg rating — 2,361,706 ratings
#  3.58 avg rating — 4,170,131 ratings
#  4.36 avg rating — 1,423,735 ratings
#  4.25 avg rating — 426,902 ratings
#  3.89 avg rating — 2,157,238 ratings
#  4.28 avg rating — 948,826 ratings
#  4.59 avg rating — 98,365 ratings
#  4.25 avg rating — 2,762,438 ratings
#  4.21 avg rating — 1,105,232 ratings
#  4.37 avg rating — 767,714 ratings
#  3.83 avg rating — 1,084,601 ratings
#  3.80 avg rating — 1,632,261 ratings
#  4.09 avg rating — 1,493,893 ratings
#  4.07 avg rating — 403,959 ratings
#  4.06 avg rating — 744,783 ratings
#  4.15 avg rating — 596,657 ratings
#  4.22 avg rating — 2,411,908 ratings
#  3.74 avg rating — 1,777,644 ratings
#  4.11 avg rating — 1,343,111 ratings
#  3.65 avg rating — 1,791,971 ratings
#  3.83 avg rating — 1,569,624 ratings
#  4.19 avg rating — 488,286 ratings
#  4.30 avg rating — 936,580 ratings
# ...

# %%
i=0
aut_nm=[]
for ea in s1:
    print(i+1,ea.get_text())
    aut_nm.append(ea.get_text())
    i+=1
# Out:
# 1 Suzanne Collins
# 2 J.K. Rowling
# 3 Harper Lee
# 4 Jane Austen
# 5 Stephenie Meyer
# 6 Markus Zusak
# 7 C.S. Lewis
# 8 George Orwell
# 9 Margaret Mitchell
# 10 J.R.R. Tolkien
# 11 John Green
# 12 Douglas Adams
# 13 Shel Silverstein
# 14 Emily Brontë
# 15 Dan Brown
# 16 Arthur Golden
# 17 Lewis Carroll
# 18 Oscar Wilde
# 19 Victor Hugo
# 20 Veronica Roth
# 21 William Shakespeare
# 22 Charlotte Brontë
# 23 William Golding
# 24 Paulo Coelho
# 25 Fyodor Dostoyevsky
# 26 Orson Scott Card
# 27 Cassandra Clare
# 28 Stephen Chbosky
# 29 Kathryn Stockett
# 30 Audrey Niffenegger
# 31 F. Scott Fitzgerald
# 32 E.B. White
# 33 L.M. Montgomery
# 34 John Steinbeck
# 35 Bram Stoker
# 36 Aldous Huxley
# 37 Gabriel García Márquez
# 38 William Goldman
# 39 Antoine de Saint-Exupéry
# 40 Frances Hodgson Burnett
# 41 Khaled Hosseini
# 42 Madeleine L'Engle
# 43 J.D. Salinger
# 44 Ray Bradbury
# 45 Mark Twain
# 46 George R.R. Martin
# 47 Alice Sebold
# 48 Rick Riordan
# 49 Maurice Sendak
# 50 Dr. Seuss
# ...

# %%
i=0
rat_list=[]
for alp in a :
    print(i+1,alp.get_text())
    rat_list.append(alp.get_text())
    i+=1
# Out:
# 1  4.33 avg rating — 5,349,156 ratings
# 2  4.47 avg rating — 1,973,661 ratings
# 3  4.26 avg rating — 3,598,198 ratings
# 4  4.25 avg rating — 2,361,706 ratings
# 5  3.58 avg rating — 4,170,131 ratings
# 6  4.36 avg rating — 1,423,735 ratings
# 7  4.25 avg rating — 426,902 ratings
# 8  3.89 avg rating — 2,157,238 ratings
# 9  4.28 avg rating — 948,826 ratings
# 10  4.59 avg rating — 98,365 ratings
# 11  4.25 avg rating — 2,762,438 ratings
# 12  4.21 avg rating — 1,105,232 ratings
# 13  4.37 avg rating — 767,714 ratings
# 14  3.83 avg rating — 1,084,601 ratings
# 15  3.80 avg rating — 1,632,261 ratings
# 16  4.09 avg rating — 1,493,893 ratings
# 17  4.07 avg rating — 403,959 ratings
# 18  4.06 avg rating — 744,783 ratings
# 19  4.15 avg rating — 596,657 ratings
# 20  4.22 avg rating — 2,411,908 ratings
# 21  3.74 avg rating — 1,777,644 ratings
# 22  4.11 avg rating — 1,343,111 ratings
# 23  3.65 avg rating — 1,791,971 ratings
# 24  3.83 avg rating — 1,569,624 ratings
# ...

# %%
s2=soup.table.find_all("tr")

# %%
listme=[]
for ec in s2:
    listme.append(ec.find("a",class_="bookTitle"))

# %%
asa=requests.get("https://www.goodreads.com/book/show/370493.The_Giving_Tree")

# %%
asa
# Out:
# <Response [200]>

# %%
page=BeautifulSoup(asa.text,"html.parser")

# %%
page.title
# Out:
# <title>
# The Giving Tree by Shel Silverstein
# </title>

# %%
auth_url=[]
for elem in listme:

        auth_url.append(elem["href"])

# %%
lisnew=[]
for elemn in auth_url:
    if "." in elemn:
        
        l=elemn.split(".")
        lisnew.append(l[1].replace("_"," "))
    else:
        lisnew.append(elemn)

# %%
auth_url
# Out:
# ['/book/show/2767052-the-hunger-games',
#  '/book/show/2.Harry_Potter_and_the_Order_of_the_Phoenix',
#  '/book/show/2657.To_Kill_a_Mockingbird',
#  '/book/show/1885.Pride_and_Prejudice',
#  '/book/show/41865.Twilight',
#  '/book/show/19063.The_Book_Thief',
#  '/book/show/11127.The_Chronicles_of_Narnia',
#  '/book/show/7613.Animal_Farm',
#  '/book/show/18405.Gone_with_the_Wind',
#  '/book/show/30.J_R_R_Tolkien_4_Book_Boxed_Set',
#  '/book/show/11870085-the-fault-in-our-stars',
#  '/book/show/11.The_Hitchhiker_s_Guide_to_the_Galaxy',
#  '/book/show/370493.The_Giving_Tree',
#  '/book/show/6185.Wuthering_Heights',
#  '/book/show/968.The_Da_Vinci_Code',
#  '/book/show/930.Memoirs_of_a_Geisha',
#  '/book/show/24213.Alice_s_Adventures_in_Wonderland_Through_the_Looking_Glass',
#  '/book/show/5297.The_Picture_of_Dorian_Gray',
#  '/book/show/24280.Les_Mis_rables',
#  '/book/show/13335037-divergent',
#  '/book/show/18135.Romeo_and_Juliet',
#  '/book/show/10210.Jane_Eyre',
# ...

# %%
for ech in lisnew:
    print(ech)
# Out:
# /book/show/2767052-the-hunger-games
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-248-509c59d5a594> in <module>()
#       1 for ech in lisnew:
#       2     print(ech)
# ----> 3     df=pd.DataFrame({"col0":ech})
#
# /media/kuldeep/seed/anypy/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     328                                  dtype=dtype, copy=copy)
#     329         elif isinstance(data, dict):
# --> 330             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     331         elif isinstance(data, ma.MaskedArray):
#     332             import numpy.ma.mrecords as mrecords
#
# /media/kuldeep/seed/anypy/lib/python3.6/site-packages/pandas/core/frame.py in _init_dict(self, data, index, columns, dtype)
#     459             arrays = [data[k] for k in keys]
#     460
# ...

# %%
auth_url[2].split(".")
# Out:
# ['/book/show/2657', 'To_Kill_a_Mockingbird']

# %%
def funky(params):
    spli=params.find("-")
    params=params[(spli+1):]
    return params

# %%
newlist=[funky(i).replace("-"," ")  if "-"in i else i for i in lisnew ]

# %%
i=0
for li in newlist:
    print(i+1,li)
    i+=1
# Out:
# 1 the hunger games
# 2 Harry Potter and the Order of the Phoenix
# 3 To Kill a Mockingbird
# 4 Pride and Prejudice
# 5 Twilight
# 6 The Book Thief
# 7 The Chronicles of Narnia
# 8 Animal Farm
# 9 Gone with the Wind
# 10 J R R Tolkien 4 Book Boxed Set
# 11 the fault in our stars
# 12 The Hitchhiker s Guide to the Galaxy
# 13 The Giving Tree
# 14 Wuthering Heights
# 15 The Da Vinci Code
# 16 Memoirs of a Geisha
# 17 Alice s Adventures in Wonderland Through the Looking Glass
# 18 The Picture of Dorian Gray
# 19 Les Mis rables
# 20 divergent
# 21 Romeo and Juliet
# 22 Jane Eyre
# 23 Lord of the Flies
# 24 The Alchemist
# 25 Crime and Punishment
# 26 Ender s Game
# 27 City of Bones
# 28 The Perks of Being a Wallflower
# 29 the help
# 30 the time traveler s wife
# 31 The Great Gatsby
# 32 Charlotte s Web
# 33 Anne of Green Gables
# 34 Of Mice and Men
# 35 Dracula
# 36 Brave New World
# 37 One Hundred Years of Solitude
# 38 The Princess Bride
# 39 The Little Prince
# 40 The Secret Garden
# ...

# %%
import re

# %%
def funy2(args):
        args=args.replace(",","")
        tmp=args.split("-")
        lia=list(map(float, re.findall(r'[-+]?[0-9]*\.?[0-9]+', args)))
        return lia[0],int(lia[1])
       # return (lia[0],lia[1])

# %%
funy2(rat_list[0])
# Out:
# (4.33, 5349156)

# %%
rating=[funy2(i) for i in rat_list]

# %%
rating[0][1]
i=0
score=[]
no_res=[]
for i in range(len(rating)):
    score.append(rating[i][0])
    no_res.append(rating[i][1])

# %%
pd.DataFrame(list(zip(lst1, lst2, lst3)),
              columns=['lst1_title','lst2_title', 'lst3_title'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-292-61b0eb1d8c35> in <module>()
# ----> 1 pd.DataFrame(list(zip(lst1, lst2, lst3)),
#       2               columns=['lst1_title','lst2_title', 'lst3_title'])
#
# NameError: name 'lst1' is not defined

# %%
pd.DataFrame(list(zip(newlist,aut_nm, score,no_res)),
              columns=['book tittle','author name', 'Rating*5',"no of respose"])
# Out:
#                                           book tittle  \
# 0                                    the hunger games
# 1           Harry Potter and the Order of the Phoenix
# 2                               To Kill a Mockingbird
# 3                                 Pride and Prejudice
# 4                                            Twilight
# 5                                      The Book Thief
# 6                            The Chronicles of Narnia
# 7                                         Animal Farm
# 8                                  Gone with the Wind
# 9                      J R R Tolkien 4 Book Boxed Set
# 10                             the fault in our stars
# 11               The Hitchhiker s Guide to the Galaxy
# 12                                    The Giving Tree
# 13                                  Wuthering Heights
# 14                                  The Da Vinci Code
# 15                                Memoirs of a Geisha
# ...
